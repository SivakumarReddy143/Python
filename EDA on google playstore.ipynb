# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
sns.boxplot(df['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
df['Rating'].mean()
# Out:
# 4.193338315362443

# %%
df['Rating'].median()
# Out:
# 4.3

# %%
df['Rating']=df['Rating'].fillna(df['Rating'].mean())

# %%
df['Rating'].unique()
# Out:
# array([ 4.1       ,  3.9       ,  4.7       ,  4.5       ,  4.3       ,
#         4.4       ,  3.8       ,  4.2       ,  4.6       ,  3.2       ,
#         4.        ,  4.19333832,  4.8       ,  4.9       ,  3.6       ,
#         3.7       ,  3.3       ,  3.4       ,  3.5       ,  3.1       ,
#         5.        ,  2.6       ,  3.        ,  1.9       ,  2.5       ,
#         2.8       ,  2.7       ,  1.        ,  2.9       ,  2.3       ,
#         2.2       ,  1.7       ,  2.        ,  1.8       ,  2.4       ,
#         1.6       ,  2.1       ,  1.4       ,  1.5       ,  1.2       ,
#        19.        ])

# %%
sns.kdeplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
df['App'].head()
# Out:
# 0       Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                  Coloring book moana
# 2    U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                Sketch - Draw & Paint
# 4                Pixel Draw - Number Art Coloring Book
# Name: App, dtype: object

# %%
df['App'].isnull().sum()
# Out:
# 0

# %%
df['App']=df['App'].astype('str')

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Category'].isnull().sum()
# Out:
# 0

# %%
df['Category']=df['Category'].astype('str')

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Reviews'].isnull().sum()
# Out:
# 0

# %%
df['Reviews'].head()
# Out:
# 0       159
# 1       967
# 2     87510
# 3    215644
# 4       967
# Name: Reviews, dtype: object

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df_copy=df

# %%
df_copy=df_copy.drop(10472)

# %%
df_copy['Reviews']=df_copy['Reviews'].astype('int')

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df_copy['Size']=df['Size'].str.replace('M','e6').str.replace('+','').str.replace(',','')
df_copy['Size']=df_copy['Size'].str.replace('k','e3')
df_copy['Size']=df_copy['Size'].replace('Varies with device',np.nan)

# %%
df_copy['Size'].unique()
# Out:
# array(['19e6', '14e6', '8.7e6', '25e6', '2.8e6', '5.6e6', '29e6', '33e6',
#        '3.1e6', '28e6', '12e6', '20e6', '21e6', '37e6', '2.7e6', '5.5e6',
#        '17e6', '39e6', '31e6', '4.2e6', '7.0e6', '23e6', '6.0e6', '6.1e6',
#        '4.6e6', '9.2e6', '5.2e6', '11e6', '24e6', nan, '9.4e6', '15e6',
#        '10e6', '1.2e6', '26e6', '8.0e6', '7.9e6', '56e6', '57e6', '35e6',
#        '54e6', '201e3', '3.6e6', '5.7e6', '8.6e6', '2.4e6', '27e6',
#        '2.5e6', '16e6', '3.4e6', '8.9e6', '3.9e6', '2.9e6', '38e6',
#        '32e6', '5.4e6', '18e6', '1.1e6', '2.2e6', '4.5e6', '9.8e6',
#        '52e6', '9.0e6', '6.7e6', '30e6', '2.6e6', '7.1e6', '3.7e6',
#        '22e6', '7.4e6', '6.4e6', '3.2e6', '8.2e6', '9.9e6', '4.9e6',
#        '9.5e6', '5.0e6', '5.9e6', '13e6', '73e6', '6.8e6', '3.5e6',
#        '4.0e6', '2.3e6', '7.2e6', '2.1e6', '42e6', '7.3e6', '9.1e6',
#        '55e6', '23e3', '6.5e6', '1.5e6', '7.5e6', '51e6', '41e6', '48e6',
# ...

# %%
df_copy['Size']=df_copy['Size'].astype('float')

# %%
df_copy['Size']
# Out:
# 0        19000000.0
# 1        14000000.0
# 2         8700000.0
# 3        25000000.0
# 4         2800000.0
#             ...
# 10836    53000000.0
# 10837     3600000.0
# 10838     9500000.0
# 10839           NaN
# 10840    19000000.0
# Name: Size, Length: 10840, dtype: float64

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy['Installs'].isnull().sum()
# Out:
# 0

# %%
df_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df_copy['Installs']=df_copy['Installs'].str.replace(',','').str.replace('+','')

# %%
df_copy['Installs']=df_copy['Installs'].astype('int')

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df['Type'].isnull().sum()
# Out:
# 1

# %%
df_copy['Type']=df_copy['Type'].fillna(df_copy['Type'].mode())

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_copy['Price']=df_copy['Price'].str.replace('$','').astype('float')

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
df_copy['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df_copy['last updated day']=pd.to_datetime(df_copy['Last Updated']).dt.day_name()

# %%
df_copy['last updated day'].head()
# Out:
# 0       Sunday
# 1       Monday
# 2    Wednesday
# 3       Friday
# 4    Wednesday
# Name: last updated day, dtype: object

# %%
df_copy['last updated month']=pd.to_datetime(df_copy['Last Updated']).dt.month_name()

# %%
df_copy['last updated year']=pd.to_datetime(df_copy['Last Updated']).dt.year

# %%
df_copy['last updated year'].head(10)
# Out:
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# 5    2017
# 6    2018
# 7    2018
# 8    2017
# 9    2018
# Name: last updated year, dtype: int32

# %% [markdown]
# <h1>EDA</h1>

# %%
df_copy[df_copy.duplicated()].shape
# Out:
# (483, 16)

# %% [markdown]
# <h1>Observation

# %% [markdown]
# <h3>dataset contains duplicate records<h3>

# %%
df_copy.drop_duplicates(inplace=True)

# %%
df_copy.shape
# Out:
# (10357, 16)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10840
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   App                 10357 non-null  object
#  1   Category            10357 non-null  object
#  2   Rating              10357 non-null  float64
#  3   Reviews             10357 non-null  int32
#  4   Size                8831 non-null   float64
#  5   Installs            10357 non-null  int32
#  6   Type                10356 non-null  object
#  7   Price               10357 non-null  float64
#  8   Content Rating      10357 non-null  object
#  9   Genres              10357 non-null  object
#  10  Last Updated        10357 non-null  object
#  11  Current Ver         10349 non-null  object
#  12  Android Ver         10355 non-null  object
#  13  last updated day    10357 non-null  object
#  14  last updated month  10357 non-null  object
# ...

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews        Size  Installs  Type  Price Content Rating  \
# 0      159  19000000.0     10000  Free    0.0       Everyone
# 1      967  14000000.0    500000  Free    0.0       Everyone
# 2    87510   8700000.0   5000000  Free    0.0       Everyone
# 3   215644  25000000.0  50000000  Free    0.0           Teen
# 4      967   2800000.0    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# ...

# %%
df_copy['last updated year']=df_copy['last updated year'].astype('int')

# %%
numerical_features=[feature for feature in df_copy.columns if df_copy[feature].dtype!='O']
categorical_features=[feature for feature in df_copy.columns if df_copy[feature].dtype=='O']

# %%
numerical_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'last updated year']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver',
#  'last updated day',
#  'last updated month']

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(15,15))
plt.suptitle('Univariate analysis of numerical features',fontsize=20,fontweight='bold',alpha=0.8,y=1)

for i in range(len(numerical_features)):
    plt.subplot(2,3,i+1)
    sns.kdeplot(df_copy[numerical_features[i]],color='purple',shade=True)

# %% [markdown]
# <h1>obsevation

# %% [markdown]
# <h4>installs,price,reviewa and size are right skewed whereas rating and last updated year are left skewed<h4>

# %% [markdown]
# <h1>categorical columns<h1>

# %%
df_copy[categorical_features].head()
# Out:
#                                                  App        Category  Type  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN  Free
# 1                                Coloring book moana  ART_AND_DESIGN  Free
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  Free
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN  Free
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN  Free
#
#   Content Rating                     Genres      Last Updated  \
# 0       Everyone               Art & Design   January 7, 2018
# 1       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2       Everyone               Art & Design    August 1, 2018
# 3           Teen               Art & Design      June 8, 2018
# 4       Everyone    Art & Design;Creativity     June 20, 2018
#
#           Current Ver   Android Ver last updated day last updated month
# ...

# %%
plt.figure(figsize=(15,15))
plt.suptitle('univariate analysis on categorical data',fontsize=30,color='green',fontweight='bold')
category=['Type','Content Rating','last updated day','last updated month','Category']
for i in range(len(category)):
    plt.subplot(3,2,i+1)
    sns.countplot(x=df_copy[category[i]],palette='Set2')
    plt.xticks(rotation=90)
    plt.tight_layout()

# %%
df['Category'].value_counts().plot.pie(y=df_copy['Category'],figsize=(15,15),autopct='%1.1f')
# Out:
# <Axes: ylabel='count'>

# %%
df_cat_installs=df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()
df_cat_installs['Installs']=df_cat_installs['Installs']/1000000000
df2=df_cat_installs.head(10)
plt.figure(figsize=(15,15))
sns.set_style('darkgrid')
ax=sns.barplot(y='Category',x='Installs',data=df2,color='#83D475')
ax.set_xlabel('installs in billions')
ax.set_title('Most popular Categories in playstore',fontsize=40,color='purple')
# Out:
# Text(0.5, 1.0, 'Most popular Categories in playstore')
